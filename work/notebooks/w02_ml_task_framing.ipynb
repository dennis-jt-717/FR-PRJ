# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# **Lane 3: Clustering (Unsupervised).** We will group content items into archetypes based on their engagement and performance metrics (ctr, scroll, engagement_rate, position). This allows us to discover natural performance groupings that guide strategy.

# %%
# Task: Lane 3 - Structured Content Archetype Clustering

# %% [markdown]
# ## 2. Target or proxy
#
# **None.** This is unsupervised. We will use numeric performance features to find archetypes. Validation will rely on silhouette scores and qualitative sense-checking of the resulting cluster profiles.

# %%
# No target (Unsupervised)

# %% [markdown]
# ## 3. Success metric
#
# **Silhouette Coefficient** and **Cluster Profiling.** We want cohesive clusters that are distinct from one another. We will validate them by verifying if they map to meaningful real-world archetypes (e.g., 'rising stars').

# %%
# Metric: Silhouette Score, Cluster separation analysis

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# One row = one unique `content_id` (using the 90-day aggregate data).

# %%
import pandas as pd
# Demonstration of data grain
df = pd.read_csv('../data/raw/content_refresh_anonymized.csv')
print(f"Grain: {df['content_id'].nunique()} unique content items.")

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# Manual rule-based categorization (e.g., 'if CTR > X and Position < Y') is arbitrary and fails to capture the high-dimensional interaction between metrics. ML clusters provide data-driven archetypes that emerge organically from the performance data.

# %%
# ML provides data-driven, non-arbitrary archetypes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
