# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane 3: Structured Content Archetype Clustering.** I chose this lane to uncover recurring performance archetypes (e.g., champions, rising stars, hidden gems) within the content inventory. This is the foundation for prioritized content strategy, as it allows us to identify groups of pages that behave alike and require similar optimization interventions.

# %%
# Focus: Lane 3 - Structured Content Archetype Clustering

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve?* It improves the decision of how to categorize content into archetypes to guide tailored strategy allocation.
# *Who acts on it?* An SEO editor or strategist.
# *What does a wrong recommendation cost?* Misclassifying an archetype (e.g., treating a 'weak/no-demand' page as a 'champion') leads to wasted editor time and ineffective resource allocation.

# %%
# Decision: Strategy allocation based on cluster-identified archetypes.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv('../data/raw/content_refresh_anonymized.csv')
print(f"Total items: {len(df)}")
print(f"Avg CTR: {df['ctr'].mean():.4f}")
print(f"Avg Engagement Rate: {df['engagement_rate'].mean():.4f}")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I will claim **directional** insights about performance archetypes based on metrics. I will not claim this is semantic (meaning-based) clustering (as no text is available), nor that this proves a causal effect on SEO rankings. This work is **decision-support** for content audit and strategy.

# %%
# Claims: directional, decision-support, observed metric-based patterns.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
