# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why

# %%
# Focus: Lane 3 - Structured Content Archetype Clustering


# Why this lane?

# Large-scale websites easily suffer from "content bloat"—managing thousands of pages manually is impossible.
# This project applies unsupervised machine learning (K-Means Clustering and Principal Component Analysis) to
#   automate content auditing. It clusters them by their behavioral footprints (how they perform) and structural
#   attributes (how they are built). It builds an automated engine that tells an organization exactly which pages
#   to protect, optimize, or delete based on hard performance data.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve?*
# *Who acts on it?*
# *What does a wrong recommendation cost?*

# %%
# What decision does your work improve?

# It improves the Resource Allocation and Content Strategy Decision. Specifically,
#   it answers: Where should the editorial and SEO team spend their limited hours
#   next quarter? Should they write new content, refresh old pieces, fix broken technical elements, or prune dead weight?


# Who acts on it?

# Content Operations Leads & Chief Editors: To assign writing/updating tasks.
# SEO Strategists: To execute technical optimizations (meta tags, internal linking, URL pruning).


# What does a wrong recommendation cost?

# If we falsely flag a "Champion" as "Weak/No-Demand" and prune (delete) it: You destroy
#   organic traffic overnight, tanking leads and revenue.

# If you mistake a "Title/CTR Problem" for a "Hidden Gem" and rewrite the whole article:
#   You waste expensive copywriting resources rewriting perfect content when all it needed was a 5-minute title tag change.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/dennis-jt-717/FlyRank-PRJ/refs/heads/main/data/raw/content_refresh_anonymized.csv')
print(f"Total items: {len(df)}")
print(f"Avg CTR: {df['ctr'].mean():.4f}")
print(f"Avg Engagement Rate: {df['engagement_rate'].mean():.4f}")
# Out:
# Total items: 30000
# Avg CTR: 0.5107
# Avg Engagement Rate: 2.5345

# %% [markdown]
# ## 4. Careful words: what I can and can't claim

# %%
# What I CAN Claim:

# Behavioral Clustering: "I am grouping URLs based on quantitative performance footprints
#   (traffic, clicks, CTR, conversions) and structural metadata (word counts, age)."

# Exploratory Lens: "The resulting archetypes are data-driven profiles designed to prioritize
#   human review and automate strategic recommendations at scale."



# What I CANNOT Claim:

# Semantic Clustering: I cannot claim the model understands the meaning, quality,
#   or topic of the pages. Because the dataset uses numeric metrics and token lengths without
#   text strings, clusters group pages that behave alike, not pages that talk about the same topic.

# Absolute Truth Labels: I cannot claim a page definitively belongs to a category forever.
#   Clustering is an exploratory tool; pages on the cluster boundaries represent transitional states.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
